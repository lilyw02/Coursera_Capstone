# %% [markdown]
# # Data obtaining

# %%
import numpy as np 
import pandas as pd 
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(response, 'lxml')

# %% [markdown]
# # Data transforming

# %%
def parse_html_table(table):
        n_columns = 0
        n_rows=0
        column_names = []
        for row in table.find_all('tr'):
            td_tags = row.find_all('td')
            if len(td_tags) > 0:
                n_rows+=1
                if n_columns == 0:
                    n_columns = len(td_tags)
                        
            th_tags = row.find_all('th') 
            if len(th_tags) > 0 and len(column_names) == 0:
                for th in th_tags:
                    column_names.append(th.get_text())
    
        if len(column_names) > 0 and len(column_names) != n_columns:
            raise Exception("Column titles do not match the number of columns")
    
        columns = column_names if len(column_names) > 0 else range(0,n_columns)
        df = pd.DataFrame(columns = columns,
                              index= range(0,n_rows))
        row_marker = 0
        for row in table.find_all('tr'):
            column_marker = 0
            columns = row.find_all('td')
            for column in columns:
                df.iat[row_marker,column_marker] = column.get_text()
                column_marker += 1
            if len(columns) > 0:
                row_marker += 1
                    
        for col in df:
            try:
                df[col] = df[col].astype(float)
            except ValueError:
                pass
            
        return df

# %%
for table in soup.find_all('table', class_="wikitable sortable"):
    df = parse_html_table(table)

# %%
df.head()
# Out:
#   Postcode           Borough     Neighbourhood\n
# 0      M1A      Not assigned      Not assigned\n
# 1      M2A      Not assigned      Not assigned\n
# 2      M3A        North York         Parkwoods\n
# 3      M4A        North York  Victoria Village\n
# 4      M5A  Downtown Toronto      Harbourfront\n

# %% [markdown]
# # Data cleaning

# %%
df = df[df.Borough != 'Not assigned']
df = df.replace('\n',' ', regex=True)
df= df[df['Neighbourhood\n'] != 'Not assigned']
df = df.groupby(['Postcode','Borough'])['Neighbourhood\n'].apply(lambda x: ", ".join(x.astype(str))).reset_index()
df = df.sample(frac=1).reset_index(drop=True)
df.head(10)
# Out:
#   Postcode           Borough  \
# 0      M9L        North York
# 1      M5J  Downtown Toronto
# 2      M9M        North York
# 3      M3H        North York
# 4      M3K        North York
# 5      M2R        North York
# 6      M5N   Central Toronto
# 7      M5A  Downtown Toronto
# 8      M5S  Downtown Toronto
# 9      M9A         Etobicoke
#
#                                      Neighbourhood\n
# 0                                     Humber Summit
# 1  Harbourfront East , Toronto Islands , Union St...
# 2                                 Emery , Humberlea
# 3  Bathurst Manor , Downsview North , Wilson Heig...
# 4                      CFB Toronto , Downsview East
# 5                                   Willowdale West
# 6                                          Roselawn
# 7                        Harbourfront , Regent Park
# 8                   Harbord , University of Toronto
# 9                                  Islington Avenue

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# # Geo info. obtaining

# %%
geo_data=pd.read_csv("http://cocl.us/Geospatial_data")
geo_data.head(10)
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476
# 5         M1J  43.744734 -79.239476
# 6         M1K  43.727929 -79.262029
# 7         M1L  43.711112 -79.284577
# 8         M1M  43.716316 -79.239476
# 9         M1N  43.692657 -79.264848

# %% [markdown]
# # Data combining

# %%
geo_data.rename(columns={'Postal Code':'Postcode'}, inplace=True)
geo_data.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %%
full_table =df.merge(geo_data, on="Postcode", how='left')
full_table.head(20)
# Out:
#    Postcode           Borough  \
# 0       M9L        North York
# 1       M5J  Downtown Toronto
# 2       M9M        North York
# 3       M3H        North York
# 4       M3K        North York
# 5       M2R        North York
# 6       M5N   Central Toronto
# 7       M5A  Downtown Toronto
# 8       M5S  Downtown Toronto
# 9       M9A         Etobicoke
# 10      M6H      West Toronto
# 11      M5L  Downtown Toronto
# 12      M7A      Queen's Park
# 13      M8X         Etobicoke
# 14      M1W       Scarborough
# 15      M2J        North York
# 16      M1N       Scarborough
# 17      M5E  Downtown Toronto
# 18      M6S      West Toronto
# 19      M4C         East York
#
#                                       Neighbourhood\n   Latitude  Longitude
# 0                                      Humber Summit   43.756303 -79.565963
# 1   Harbourfront East , Toronto Islands , Union St...  43.640816 -79.381752
# 2                                  Emery , Humberlea   43.724766 -79.532242
# 3   Bathurst Manor , Downsview North , Wilson Heig...  43.754328 -79.442259
# 4                       CFB Toronto , Downsview East   43.737473 -79.464763
# 5                                    Willowdale West   43.782736 -79.442259
# 6                                           Roselawn   43.711695 -79.416936
# 7                         Harbourfront , Regent Park   43.654260 -79.360636
# 8                    Harbord , University of Toronto   43.662696 -79.400049
# 9                                   Islington Avenue   43.667856 -79.532242
# 10                     Dovercourt Village , Dufferin   43.669005 -79.442259
# 11                   Commerce Court , Victoria Hotel   43.648198 -79.379817
# 12                                      Not assigned   43.662301 -79.389494
# 13   The Kingsway , Montgomery Road , Old Mill North   43.653654 -79.506944
# 14                    L'Amoreaux West , Steeles West   43.799525 -79.318389
# 15                    Fairview , Henry Farm , Oriole   43.778517 -79.346556
# 16                      Birch Cliff , Cliffside West   43.692657 -79.264848
# 17                                       Berczy Park   43.644771 -79.373306
# 18                               Runnymede , Swansea   43.651571 -79.484450
# 19                                  Woodbine Heights   43.695344 -79.318389
